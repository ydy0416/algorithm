# %%
from itertools import combinations
from collections import Counter


def solution(orders, course):
    answer = []
    for c in course:
        temp = []
        for order in orders:
            combi = list(combinations(sorted(order), c))
            temp += combi
        counter = Counter(temp)
        
        if len(counter) != 0 and max(counter.values()) != 1:
            for f in counter:
                print(counter)
                print(counter[f])
                if counter[f]==max(counter.values()):
                    answer+=''.join(f)
#             answer += [''.join(f) for f in counter if counter[f] == max(counter.values())]

    return sorted(answer)

orders=["BACFG", "AC", "CDE", "ACDE", "BCFG", "ACDEH"]
course=[2,3,4]

solution(orders,course)
# Out:
# Counter({('A', 'C'): 4, ('C', 'D'): 3, ('C', 'E'): 3, ('D', 'E'): 3, ('B', 'C'): 2, ('B', 'F'): 2, ('B', 'G'): 2, ('C', 'F'): 2, ('C', 'G'): 2, ('F', 'G'): 2, ('A', 'D'): 2, ('A', 'E'): 2, ('A', 'B'): 1, ('A', 'F'): 1, ('A', 'G'): 1, ('A', 'H'): 1, ('C', 'H'): 1, ('D', 'H'): 1, ('E', 'H'): 1})
# 1
# Counter({('A', 'C'): 4, ('C', 'D'): 3, ('C', 'E'): 3, ('D', 'E'): 3, ('B', 'C'): 2, ('B', 'F'): 2, ('B', 'G'): 2, ('C', 'F'): 2, ('C', 'G'): 2, ('F', 'G'): 2, ('A', 'D'): 2, ('A', 'E'): 2, ('A', 'B'): 1, ('A', 'F'): 1, ('A', 'G'): 1, ('A', 'H'): 1, ('C', 'H'): 1, ('D', 'H'): 1, ('E', 'H'): 1})
# 4
# Counter({('A', 'C'): 4, ('C', 'D'): 3, ('C', 'E'): 3, ('D', 'E'): 3, ('B', 'C'): 2, ('B', 'F'): 2, ('B', 'G'): 2, ('C', 'F'): 2, ('C', 'G'): 2, ('F', 'G'): 2, ('A', 'D'): 2, ('A', 'E'): 2, ('A', 'B'): 1, ('A', 'F'): 1, ('A', 'G'): 1, ('A', 'H'): 1, ('C', 'H'): 1, ('D', 'H'): 1, ('E', 'H'): 1})
# 1
# ...

# %%
# https://velog.io/@jwisgenius/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EC%8A%A4-LV2-%EB%A9%94%EB%89%B4-%EB%A6%AC%EB%89%B4%EC%96%BC

from itertools import combinations
orders=["BACFG", "AC", "CDE", "ACDE", "BCFG", "ACDEH"]
course=[2,3,4]

#orders 각 원소 정렬
orders2=[[] for i in range(len(orders))]
k=0
for i in orders:
    for j in i:
        orders2[k].append(j)
    k+=1
for i in range(len(orders2)):
    orders2[i].sort()

orders3=[]
for i in orders2:
    temp=''
    for j in i:
        temp+=j
    orders3.append(temp)
print(orders3)
        
#중복없이 합친것
hap=[]
for i in orders:
    for j in i:
        hap.append(j)
hap=list(set(hap))
hap.sort()

#조합만들기
case_set=[]
for i in course:
    combi=list(combinations(hap,i))
    case_set.append(combi)

case_set2=[]
for case in case_set:
    for i in case:
        temp=''
        for k in i:
            temp+=k
        case_set2.append(temp)

hubo=[]
for case in case_set2:
    for i in orders3:
        if case in i:
            hubo.append(case)


answer=[]
# Out:
# ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-bb7cb96dd608> in <module>
#      50         if case in i:
#      51             hubo.append(case)
# ---> 52 counter(hubo)
#      53
#      54 answer=[]
#
# NameError: name 'counter' is not defined
